# %%
import numpy as np
import scipy
import scipy.special
from scipy.fft import fft2, fftfreq, ifft2, fftshift, ifftshift
import matplotlib.pyplot as plt
from IPython.display import display
import threading
from io import StringIO 
import sys
import ipywidgets as widgets
import math
import os


import plotly
import plotly.graph_objs as go


import diffractsim
diffractsim.set_backend("CPU")
from diffractsim import nm, mm, cm, um

from PIL import Image

# %% [markdown]
# Let's reproduce the OAM mode sorter posited by Robert Fickler et al.

# %% [markdown]
# # Implementation using Functions

# %%
# Fresnel Propagator Function

'''
This propagates the beam using a Fresnal Diffraction Transfer Function approach. 

PARAMETERS
u1 - source plane
L - length of the numerical window (in units of w0)
la - lambda (m-1)
z - propagation distance (w0)
'''

def propTF(u1,L,la,z):
    M,nn=u1.shape
    dx=L/M
    fx=np.arange(-1/(2*dx),1/(2*dx),1/L)
    Fx, Fy = np.meshgrid(fx, fx)
    H=np.exp(-1j*np.pi*la*z*(Fx**2+Fy**2))
    
    H = fftshift(H)
    U2=H*fft2(fftshift(u1))
    u2=ifftshift(ifft2(U2))

    
    return u2 


'''
This function implements the Fraufoner Diffraction Transfer Approach instead. Translation from Voelz
u1 - source field
L1 - full observation side length 
la - wavelength 
z - prop distance


returns: 
u2 - observation field at z
L2 - observation field side lengths
'''

def propFF(u1, L1, la, z, isInverse = False):
    #Some initial calcs from the source field
    
    M, nn = np.shape(u1)
    dx1 = L1/M
    k = 2*np.pi/la
    
    # compute params for observation plane
    
    L2 = (la*z)/dx1
    dx2 = (la*z)/L1
    
    # compute field at observation plane 
    x2 = np.arange(-L2/2,L2/2,dx2)
    
    xx2, yy2 = np.meshgrid(x2, x2)
    
    # Fraufofner transfer function? 

    c = (1/(1j*la*z))*np.exp(1j*(k/2*z)*(xx2**2 + yy2**2))
    
    if(isInverse):
        u2 = c*fftshift(ifft2(ifftshift(u1)))*dx1**2
        
    else:
        u2 = c*ifftshift(fft2(fftshift(u1)))*dx1**2
    
    return u2, L2



# LG modes 

'''
# Generates the normalized LG field.
# Expression adapted from Saleh. The normalization factor is adapted from wikipedia, 
# then modified silghtly so that the LG mode expression in wikipedia and Saleh are equivalent
#
# RHO, PHI - polar coordinate field
# ell - azimuthal index
# p - radial index
# w0 - beam waist (in units of ... w0)
# h - grid step size
# z - propagation distance
# k - wavenumber
'''

def LG(RHO,PHI,ell,p,w0,h,z,k):
    wL = (2*np.pi)/(k)
    z_o = np.pi*w0**2/wL
    w_z = lambda z: w0*np.sqrt(1 + (z/z_o)**2)
    R_z = lambda z: z*(1+(z_o/z)**2)
    zeta_z = lambda z: np.arctan(z/z_o)

    N_factor = 1
    if (z == 0):
        AK = N_factor * np.exp(-(RHO/w0)**2) * ((RHO/w0)**abs(ell) * 
                                                    scipy.special.eval_genlaguerre(p,abs(ell),2*(RHO/w0)**2) * np.exp(1j * ell * phi))
    else:
        AK = N_factor * (w0/w_z(z)) * np.exp(-(RHO/w_z(z))**2) * ((RHO/w_z(z))**abs(ell) * 
                                                    scipy.special.eval_genlaguerre(p,abs(ell),2*(RHO/w_z(z))**2) * np.exp(1j * ell * phi))*np.exp(-1j*k*z) * np.exp(-1j*k*(RHO**2/(2*R_z(z)))) * np.exp(1j*(abs(ell)+2*p + 1)*zeta_z(z))
    reNormFactor = np.sqrt(np.sum(np.conj(AK)*AK * h**2)) # We use this to further normalize the field with respect to 
    return  AK/reNormFactor

'''
Generates knots
# This function intialises the knot field that we want to generate.
# rr, phi - field coordinates
# w0 - input beam waist (in mm)
# knotType - string - selects the polynomial characteristic of the knot
# shapeParams - float list - list of knot parameters (a,b,kk) expected
'''

def setKnotType(rr, phi, w0,  knotType, shapeParams): 
    
    rs = rr/w0 # dimensionless, scaled beam coordinate
    a,b,kk = shapeParams
    
    if (knotType == 'Trefoil'): # Input beam profile (Trefoil)
        AK=np.exp(-(rs/(np.sqrt(2)*kk))**2)*(1 - rs**2 - 4 * (a**2 - b**2) * rs**3 - rs**4 + rs**6 - 2 *(a - b)**2 * (rs*np.exp(-1j*phi))**3 - 2 *(a + b)**2 * (rs*np.exp(1j*phi))**3)
    
    if (knotType == 'Hopflink'): # Input beam profile (Hopf Link)
        AK = (1 - 2*(1+a**2 - b**2)*rs**2 + rs**4 - 2*(a**2 + b**2)*np.cos(2*phi)*rs**2 - 1j*4*a*b*np.sin(2*phi)*rs**2)*np.exp(-(rs/(np.sqrt(2)*kk))**2)

    if (knotType == 'Cinquefoil'): # Input beam profile (Cinquefoil)
        AK = np.exp(-(rs/(np.sqrt(2)*kk))**2) * (1 + rs**2 - 2*rs**4 - 16*(a**2 - b**2)*rs**5 - 2*rs**6 + rs**8 + rs**10 - (8*((a-b)**2)*(rs**5)*np.exp(-1j*5*(phi))) - (8*((a+b)**2)*(rs**5)*np.exp(1j*5*(phi))))
   
    return AK


# Function which plots the phase and intensity of the field

'''
Jointly plots the intensity and phase patterns of the complex field.

Ex - complex 2D array -  field
'''

def TotInt(Ex):
    fig, ax =  plt.subplots(1,2,figsize=(10,10))
    ax[0].set_title('Intensity')
    intensity = ax[0].imshow(abs(Ex)**2,cmap="gist_gray")
    ax[0].axis('off')
    cbar=fig.colorbar(intensity, ax=ax[0])
    
    ax[1].set_title('Phase')
    phase = ax[1].imshow(np.angle(Ex), cmap="hsv", interpolation='nearest')
    ax[1].axis('off')
    cbar=fig.colorbar(phase, ax=ax[1])
    plt.show()
    
    
'''
Cartesian to Polar coordinates 
x,y - x and y coordinates
'''

def cart2pol(x, y):
    rho = np.sqrt((x)**2 + (y)**2)
    phi = np.arctan2(y, x)
    return(rho, phi)



def lens_phase(rr,lens_rad, k, f): 
    t = 1
    pupil_func = (np.where(rr**2 < lens_rad**2,t, np.zeros_like(xx)))
    trans_func = pupil_func*np.exp(-1j*(2*k/f)*(r)**2)
    
    return pupil_func*np.exp(-1j*(2*k/f)*(r)**2)



# Pupil function which we convolve with the outgoing field 

def pupil_function(rr, lens_rad):
    t = 1
    return (np.where(rr**2 < lens_rad**2,t, np.zeros_like(rr)))
    

def random_phase(xx,yy):
    t = 1
    res = len(xx)
    
    x_min = random.uniform(0,1)
    x_max = x_min + random.uniform(0.5,1) # How much of the plate do we want to shine?
    y_min = random.uniform(0,1)
    y_max = y_min + random.uniform(0.5,1)
            
    x = np.linspace(x_min, x_max, res)
    y = np.linspace(y_min, y_max, res)

    X, Y = np.meshgrid(x, y)
    silt_func = generate_random_function(X, Y, -1, 1, 2, 3, math.radians(5))
    return np.exp(-1j*np.pi*silt_func)

# %% [markdown]
# Defining the coordinate space

# %%
# Define the coordinate space 

la = 0.5*um
k=(2*np.pi)/la  # [m^-1] wavenumber    
maxx = 1.5 * mm # Full length of the numerical window (m)
N=128 # [Number of points per dimension]

# Space definition 
dx = maxx/N
dy = maxx/N 

#okay let's just say h here is dx or dy for now WLOG (WITH ... loss of generality)
h = dx

X = dx*(np.arange(N) - N //2)
Y = dy*(np.arange(N) - N //2)

print(X)

xx,yy=np.meshgrid(X,Y);
r, phi= cart2pol(xx,yy)
# Out:
# [-7.5000000e-04 -7.3828125e-04 -7.2656250e-04 -7.1484375e-04
#  -7.0312500e-04 -6.9140625e-04 -6.7968750e-04 -6.6796875e-04
#  -6.5625000e-04 -6.4453125e-04 -6.3281250e-04 -6.2109375e-04
#  -6.0937500e-04 -5.9765625e-04 -5.8593750e-04 -5.7421875e-04
#  -5.6250000e-04 -5.5078125e-04 -5.3906250e-04 -5.2734375e-04
#  -5.1562500e-04 -5.0390625e-04 -4.9218750e-04 -4.8046875e-04
#  -4.6875000e-04 -4.5703125e-04 -4.4531250e-04 -4.3359375e-04
#  -4.2187500e-04 -4.1015625e-04 -3.9843750e-04 -3.8671875e-04
#  -3.7500000e-04 -3.6328125e-04 -3.5156250e-04 -3.3984375e-04
#  -3.2812500e-04 -3.1640625e-04 -3.0468750e-04 -2.9296875e-04
#  -2.8125000e-04 -2.6953125e-04 -2.5781250e-04 -2.4609375e-04
#  -2.3437500e-04 -2.2265625e-04 -2.1093750e-04 -1.9921875e-04
#  -1.8750000e-04 -1.7578125e-04 -1.6406250e-04 -1.5234375e-04
#  -1.4062500e-04 -1.2890625e-04 -1.1718750e-04 -1.0546875e-04
#  -9.3750000e-05 -8.2031250e-05 -7.0312500e-05 -5.8593750e-05
#  -4.6875000e-05 -3.5156250e-05 -2.3437500e-05 -1.1718750e-05
#   0.0000000e+00  1.1718750e-05  2.3437500e-05  3.5156250e-05
#   4.6875000e-05  5.8593750e-05  7.0312500e-05  8.2031250e-05
#   9.3750000e-05  1.0546875e-04  1.1718750e-04  1.2890625e-04
#   1.4062500e-04  1.5234375e-04  1.6406250e-04  1.7578125e-04
#   1.8750000e-04  1.9921875e-04  2.1093750e-04  2.2265625e-04
#   2.3437500e-04  2.4609375e-04  2.5781250e-04  2.6953125e-04
#   2.8125000e-04  2.9296875e-04  3.0468750e-04  3.1640625e-04
#   3.2812500e-04  3.3984375e-04  3.5156250e-04  3.6328125e-04
#   3.7500000e-04  3.8671875e-04  3.9843750e-04  4.1015625e-04
#   4.2187500e-04  4.3359375e-04  4.4531250e-04  4.5703125e-04
#   4.6875000e-04  4.8046875e-04  4.9218750e-04  5.0390625e-04
#   5.1562500e-04  5.2734375e-04  5.3906250e-04  5.5078125e-04
#   5.6250000e-04  5.7421875e-04  5.8593750e-04  5.9765625e-04
#   6.0937500e-04  6.2109375e-04  6.3281250e-04  6.4453125e-04
#   6.5625000e-04  6.6796875e-04  6.7968750e-04  6.9140625e-04
#   7.0312500e-04  7.1484375e-04  7.2656250e-04  7.3828125e-04]

# %% [markdown]
# Testing out the pupil function

# %%
spotty = pupil_function(r, 0.1*mm)
TotInt(spotty)

# %% [markdown]
# Defining multiple spots

# %%
num_of_output_chans = 3

def output_chan(X, Y, rad_spot, maxx, num_of_spots):
    N = len(X)
    spot_loc_x = []
    spot_loc_y = []
    
    for ii in range(num_of_spots):
        spot_loc_x.append(np.random.uniform(-maxx+rad_spot,maxx-rad_spot))
        spot_loc_y.append(np.random.uniform(-maxx+rad_spot,maxx-rad_spot))
    
    print(spot_loc_x)
    
    fields = np.empty((num_of_spots, N, N), dtype=np.complex64)
    # Space definition 
    for ii in range(num_of_spots):
        X=np.linspace(-maxx,maxx,N) + spot_loc_x[ii]
        Y=np.linspace(-maxx,maxx,N) + spot_loc_y[ii]
        h=np.abs(X[1]-X[2]) # Step size
        xx,yy=np.meshgrid(X,Y)
        r, phi= cart2pol(xx,yy)
        
        fields[ii] = pupil_function(r, rad_spot)
    
    return fields, spot_loc_x, spot_loc_y # In principle, it suffices to return fields. 

output_chans, spot_loc_x, spot_loc_y = output_chan(X,Y,0.2*mm,maxx,num_of_output_chans)
TotInt(output_chans[1])
# Out:
# [-0.0012550393243553788, -0.0006986789194714362, -7.810361893662758e-05]

# %% [markdown]
# Generating the LG beam

# %%
# Generating an LG mode as a test
field = LG(r, phi, 1, 1, 0.1*mm,h,0,k)
field = field / np.max(np.abs(field))
TotInt(field)

# %% [markdown]
# Let's get knotty

# %%
shapeParams = [1,1,1.2]
knotType = 'Trefoil'
w0 = 0.05*mm

# setKnotType(rr, phi, w0,  knotType, shapeParams)
field = setKnotType(r, phi, w0, knotType, shapeParams)
TotInt(field)

# %% [markdown]
# Now we propagate the beam towards the fourier length of the lens. Note that we are using Fraunhofer diffraction as we don't have to sample nearly as much. The solution of a beam propagating through a lens also comes out directly w/ z= the focal length of the lens. Here, we assume that the beam is in the back fourier plane.

# %%
temp_1 = field
prop_dist = 10*cm

# Propagate the lens field to the focal plain of the lens

field_lens,_ = propFF(temp_1, maxx, la, prop_dist)

field_lens = field_lens/np.max(np.abs(field_lens))

# Propagate again immediately before the second lens

field_lens_2 = propFF(field_lens, maxx, la, prop_dist, isInverse=True)[0]

TotInt(field_lens_2)

# %% [markdown]
# To verify that what we see adds up, let's actually just compute the phase of the (inverse) fourier transform

# %%
fourField = fftshift(fft2(temp_1))
invFourField = ifft2(ifftshift(fourField))
TotInt(fourField)
TotInt(invFourField)

# %% [markdown]
# # Computing the Sorting Probability

# %% [markdown]
# We'll need to define the fitness function, which is the sorting performance. For testing purposes, let's define a field having a gaussian beam at one of the three output_channels

# %%
X_gauss=np.linspace(-maxx,maxx,N) + spot_loc_x[0]
Y_gauss=np.linspace(-maxx,maxx,N) + spot_loc_y[0]

h_gauss=np.abs(X[1]-X[2]) # Step size
xx_gauss,yy_gauss=np.meshgrid(X_gauss,Y_gauss)
r_gauss, phi_gauss= cart2pol(xx_gauss,yy_gauss)

# plotting the gaussian field 
gauss_field = LG(r_gauss, phi_gauss, 0, 0, 0.1*mm,h,0,k)
TotInt(gauss_field)
TotInt(np.sum(output_chans, axis=0))

# %% [markdown]
# We now compute the sorting performance. This can be done by taking the incident field and convolving it with the pupil array.

# %%
# To normalize, we define the maximum sorting performance, which is the sum of intensities of each output channel

# max_output_intensity = np.sum(output_chans)

# plt.imshow(output_chans[0])

sorting_performance = 0 
ii = 0 # This defines mode n

# Define full set of indices, as you would summing through a for loop

full_index = np.arange(len(output_chans))   

# Delete ii from the list of full_index, creating a new temporary array
temp_index = np.delete(full_index, ii)
# Sum up the "incorrect" channels 
incorrect_chans = 0
for ind in temp_index:
    field_in_pupil = gauss_field*output_chans[ind]
    incorrect_chans += np.abs(field_in_pupil)**2
# Now, evaluate the sorting performance 
sorting_performance += np.abs(gauss_field*output_chans[ii])**2 - incorrect_chans

# %% [markdown]
# # Genetic Algorithm

# %%
# Let's define a class that holds an OAM mode and its correponding output channel, defined from its centre

class oamModes():
    def __init__(self, oamBeam, output_chan_field):
        self.oamBeam = oamBeam 
        self.output_chan_field = output_chan_field

# %% [markdown]
# Create an array consisting of n OAM elements and m output channels

# %%
num_of_output_chans = 3
output_chans, spot_loc_x, spot_loc_y = output_chan(X,Y,0.1*mm,maxx,num_of_output_chans)

# Now create a list containing 'oamMode' objects 

list_of_OAMs = [oamModes(LG(r, phi, 1, 0, 0.2*mm,h,0,k), output_chans[0]), oamModes(LG(r, phi, -1, 0, 0.2*mm,h,0,k), output_chans[1])]

#field = LG(r, phi, 1, 0, 0.2*mm,h,0,k)
#TotInt(field)
# Out:
# [-0.0003616828974162497, -0.0006306812064588153, -0.000750811592825094]

# %%
plt.imshow(np.abs(output_chans[0])**2, cmap = 'Greys')

# %% [markdown]
# We ... flatten them???

# %%
random_phase_modulation_1 = np.random.uniform(-np.pi, np.pi, size=(N,N))
random_phase_modulation_2 = np.random.uniform(-np.pi, np.pi, size=(N,N))

flattened_phase_1 = random_phase_modulation_1.flatten()
flattened_phase_2 = random_phase_modulation_2.flatten()

# %% [markdown]
# Define the fitness function. This will be the sorting performance function that we computed earlier

# %%
fourier_lens = 10*cm 

# Compute output channels

# num_of_output_chans = 2

# output_chans, _, _ = output_chan(X,Y,0.2*mm,maxx,num_of_output_chans)

def fitness_func(ga_instance, solution, solution_idx):

    # Create the phase map by reshaping the solution array

    reshape_phase_1 = np.reshape(a=solution[0:N**2], newshape = (N,N))
    reshape_phase_2 = np.reshape(a=solution[N**2:2*N**2], newshape=(N,N))
    phase_map_1 = np.exp(1j*reshape_phase_1)
    phase_map_2 = np.exp(1j*reshape_phase_2)
    
    # Now, this is the fitness parameter 

    sorting_performance = 0  

    for ii in range(len(list_of_OAMs)):

        # Define initial OAM field and correct output channel 

        field = list_of_OAMs[ii].oamBeam 

        # modulate the field by the first phase map 

        field_mod_1 = field*phase_map_1

        # let's simulate the propagation of the lens

        field_lens, _ = propFF(field_mod_1,maxx,la,fourier_lens)

        # modulate the field by the second phase map 

        field_mod_2 = field_lens*phase_map_2

        # simulate the lens field again. This is the final field. 

        field_lens_2, _ = propFF(field_mod_2, maxx, la, fourier_lens)

        # compute the field intensity 

        final_field_int = np.abs(field_lens_2)**2

        # Define full set of indices, as you would summing through a for loop

        full_index = np.arange(len(output_chans))   

        # Delete ii from the list of full_index, creating a new temporary array

        temp_index = np.delete(full_index, ii)

        # Sum up the "incorrect" channels 

        incorrect_chans = 0

        for ind in temp_index:
            field_in_pupil = final_field_int*output_chans[ind]
            incorrect_chans += np.abs(field_in_pupil)**2

        # Now, evaluate the sorting performance 

        correct_chans = np.abs(final_field_int*output_chans[ii])**2

        sorting_performance += correct_chans - incorrect_chans 

    return np.mean(sorting_performance)

# %%
TotInt(list_of_OAMs[1].oamBeam)

# %% [markdown]
# Parameters for the genetic algorithm. For ease, we store them in a yaml file.

# %%
import pygad
import yaml 
from yaml import Loader 

num_generations = 100000
num_parents_mating =  2

fitness_function = fitness_func 

sol_per_pop = 10 # number of parents in the population?? 
num_genes = 2*len(flattened_phase_1) # This would refer to the number of parameters in our DNA

# Lower and upper-bound ranges of the parameterization. 

init_range_low = -np.pi
init_range_high = np.pi

parent_selection_type = "rank"
#K_tournament = 5 # number of contestants, essentially
#keep_elitism  = 1

crossover_type = "single_point"

mutation_type = "random"
mutation_percent_genes = 10 # probability of mutation 

# This function keeps track of the generation number + best fitness

def on_gen(ga_instance):
    print("Generation : ", ga_instance.generations_completed)
    print("Fitness of the best solution :", ga_instance.best_solution()[1])
    
    # Checkpoint current best model?
    
    instance_name = 'first_trial'
    
    # Save phase patterns of GA instance itself 
    reshape_phase_1 = np.reshape(a=solution[0:N**2], newshape = (N,N))
    reshape_phase_2 = np.reshape(a=solution[N**2:2*N**2], newshape=(N,N))
    
    with ("best_phases)
    
    
    
    
    
    ga_instance.save(filename=f'genetic_instances/{instance_name}')
    
    # Save plot every 100 generations 
    
    if (ga_instance.generations_completed % 100 == 0):
        plt.figure()
        plt.plot(ga_instance.best_solutions_fitness)
        plt.savefig(f"plots/fitness_{ga_instance.generations_completed}.jpg")
        plt.show()

# %% [markdown]
# Create the GA instance

# %%
ga_instance = pygad.GA(num_generations=num_generations,
                       num_parents_mating=num_parents_mating,
                       fitness_func=fitness_function,
                       sol_per_pop=sol_per_pop,
                       num_genes=num_genes,
                       init_range_low=init_range_low,
                       init_range_high=init_range_high,
                       parent_selection_type=parent_selection_type,
                       crossover_type=crossover_type,
                       mutation_type=mutation_type,
                       mutation_percent_genes=mutation_percent_genes,
                       on_generation=on_gen)

# %% [markdown]
# Now run the GA

# %%
import matplotlib.pyplot as plt

ga_instance.run()
ga_instance.plot_fitness()
plt.savefig('plots/figgy.png')
# Out:
# Generation :  13505
# Fitness of the best solution : 18381867.866039466
# Generation :  13506
# Fitness of the best solution : 18381867.866039466
# Generation :  13507
# Fitness of the best solution : 18381867.866039466
# Generation :  13508
# Fitness of the best solution : 18381867.866039466
# Generation :  13509
# Fitness of the best solution : 18381867.866039466
# Generation :  13510
# Fitness of the best solution : 18381867.866039466
# Generation :  13511
# Fitness of the best solution : 18381867.866039466
# Generation :  13512
# Fitness of the best solution : 18381867.866039466
# Generation :  13513
# Fitness of the best solution : 18381867.866039466
# Generation :  13514
# Fitness of the best solution : 18381867.866039466
# Generation :  13515
# Fitness of the best solution : 18381867.866039466
# Generation :  13516
# Fitness of the best solution : 18381867.866039466
# Generation :  13517
# Fitness of the best solution : 18381867.866039466
# Generation :  13518
# Fitness of the best solution : 18381867.866039466
# Generation :  13519
# Fitness of the best solution : 18381867.866039466
# Generation :  13520
# Fitness of the best solution : 18381867.866039466
# Generation :  13521
# Fitness of the best solution : 18381867.866039466
# Generation :  13522
# Fitness of the best solution : 18381867.866039466
# Generation :  13523
# Fitness of the best solution : 18381867.866039466
# Generation :  13524
# Fitness of the best solution : 18381867.866039466
# Generation :  13525
# Fitness of the best solution : 18381867.866039466
# Generation :  13526
# Fitness of the best solution : 18381867.866039466
# Generation :  13527
# Fitness of the best solution : 18381867.866039466
# Generation :  13528
# Fitness of the best solution : 18381867.866039466
# Generation :  13529
# Fitness of the best solution : 18381867.866039466
# Generation :  13530
# Fitness of the best solution : 18381867.866039466
# Generation :  13531
# Fitness of the best solution : 18381867.866039466
# Generation :  13532
# Fitness of the best solution : 18381867.866039466
# Generation :  13533
# Fitness of the best solution : 18381867.866039466
# Generation :  13534
# Fitness of the best solution : 18381867.866039466
# Generation :  13535
# Fitness of the best solution : 18381867.866039466
# Generation :  13536
# Fitness of the best solution : 18381867.866039466
# Generation :  13537
# Fitness of the best solution : 18381867.866039466
# Generation :  13538
# Fitness of the best solution : 18381867.866039466
# Generation :  13539
# Fitness of the best solution : 18381867.866039466
# Generation :  13540
# Fitness of the best solution : 18381867.866039466
# Generation :  13541
# Fitness of the best solution : 18381867.866039466
# Generation :  13542
# Fitness of the best solution : 18381867.866039466
# Generation :  13543
# Fitness of the best solution : 18381867.866039466
# Generation :  13544
# Fitness of the best solution : 18381867.866039466
# Generation :  13545
# Fitness of the best solution : 18381867.866039466
# Generation :  13546
# Fitness of the best solution : 18381867.866039466
# Generation :  13547
# Fitness of the best solution : 18381867.866039466
# Generation :  13548
# Fitness of the best solution : 18381867.866039466
# Generation :  13549
# Fitness of the best solution : 18381867.866039466
# Generation :  13550
# Fitness of the best solution : 18381867.866039466
# Generation :  13551
# Fitness of the best solution : 18381867.866039466
# Generation :  13552
# Fitness of the best solution : 18381867.866039466
# Generation :  13553
# Fitness of the best solution : 18381867.866039466
# Generation :  13554
# Fitness of the best solution : 18381867.866039466
# Generation :  13555
# Fitness of the best solution : 18381867.866039466
# Generation :  13556
# Fitness of the best solution : 18381867.866039466
# Generation :  13557
# Fitness of the best solution : 18381867.866039466
# Generation :  13558
# Fitness of the best solution : 18381867.866039466
# Generation :  13559
# Fitness of the best solution : 18381867.866039466
# Generation :  13560
# Fitness of the best solution : 18381867.866039466
# Generation :  13561
# Fitness of the best solution : 18381867.866039466
# Generation :  13562
# Fitness of the best solution : 18381867.866039466
# Generation :  13563
# Fitness of the best solution : 18381867.866039466
# Generation :  13564
# Fitness of the best solution : 18381867.866039466
# Generation :  13565
# Fitness of the best solution : 18381867.866039466
# Generation :  13566
# Fitness of the best solution : 18381867.866039466
# Generation :  13567
# Fitness of the best solution : 18381867.866039466
# Generation :  13568
# Fitness of the best solution : 18381867.866039466
# Generation :  13569
# Fitness of the best solution : 18381867.866039466
# Generation :  13570
# Fitness of the best solution : 18381867.866039466
# Generation :  13571
# Fitness of the best solution : 18381867.866039466
# Generation :  13572
# Fitness of the best solution : 18381867.866039466
# Generation :  13573
# Fitness of the best solution : 18381867.866039466
# Generation :  13574
# Fitness of the best solution : 18381867.866039466
# Generation :  13575
# Fitness of the best solution : 18381867.866039466
# Generation :  13576
# Fitness of the best solution : 18381867.866039466
# Generation :  13577
# Fitness of the best solution : 18381867.866039466
# Generation :  13578
# Fitness of the best solution : 18381867.866039466
# Generation :  13579
# Fitness of the best solution : 18381867.866039466
# Generation :  13580
# Fitness of the best solution : 18381867.866039466
# Generation :  13581
# Fitness of the best solution : 18381867.866039466
# Generation :  13582
# Fitness of the best solution : 18381867.866039466
# Generation :  13583
# Fitness of the best solution : 18381867.866039466
# Generation :  13584
# Fitness of the best solution : 18381867.866039466
# Generation :  13585
# Fitness of the best solution : 18381867.866039466
# Generation :  13586
# Fitness of the best solution : 18381867.866039466
# Generation :  13587
# Fitness of the best solution : 18381867.866039466
# Generation :  13588
# Fitness of the best solution : 18381867.866039466
# Generation :  13589
# Fitness of the best solution : 18381867.866039466
# Generation :  13590
# Fitness of the best solution : 18381867.866039466
# Generation :  13591
# Fitness of the best solution : 18381867.866039466
# Generation :  13592
# Fitness of the best solution : 18381867.866039466
# Generation :  13593
# Fitness of the best solution : 18381867.866039466
# Generation :  13594
# Fitness of the best solution : 18381867.866039466
# Generation :  13595
# Fitness of the best solution : 18381867.866039466
# Generation :  13596
# Fitness of the best solution : 18381867.866039466
# Generation :  13597
# Fitness of the best solution : 18381867.866039466
# Generation :  13598
# Fitness of the best solution : 18381867.866039466
# Generation :  13599
# Fitness of the best solution : 18381867.866039466
# Generation :  13600
# Fitness of the best solution : 18381867.866039466
# Generation :  13601
# Fitness of the best solution : 18381867.866039466
# Generation :  13602
# Fitness of the best solution : 18381867.866039466
# Generation :  13603
# Fitness of the best solution : 18381867.866039466
# Generation :  13604
# Fitness of the best solution : 18381867.866039466
# Generation :  13605
# Fitness of the best solution : 18381867.866039466
# Generation :  13606
# Fitness of the best solution : 18381867.866039466
# Generation :  13607
# Fitness of the best solution : 18381867.866039466
# Generation :  13608
# Fitness of the best solution : 18381867.866039466
# Generation :  13609
# Fitness of the best solution : 18381867.866039466
# Generation :  13610
# Fitness of the best solution : 18381867.866039466
# Generation :  13611
# Fitness of the best solution : 18381867.866039466
# Generation :  13612
# Fitness of the best solution : 18381867.866039466
# Generation :  13613
# Fitness of the best solution : 18381867.866039466
# Generation :  13614
# Fitness of the best solution : 18381867.866039466
# Generation :  13615
# Fitness of the best solution : 18381867.866039466
# Generation :  13616
# Fitness of the best solution : 18381867.866039466
# Generation :  13617
# Fitness of the best solution : 18381867.866039466
# Generation :  13618
# Fitness of the best solution : 18381867.866039466
# Generation :  13619
# Fitness of the best solution : 18381867.866039466
# Generation :  13620
# Fitness of the best solution : 18381867.866039466
# Generation :  13621
# Fitness of the best solution : 18381867.866039466
# Generation :  13622
# Fitness of the best solution : 18381867.866039466
# Generation :  13623
# Fitness of the best solution : 18381867.866039466
# Generation :  13624
# Fitness of the best solution : 18381867.866039466
# Generation :  13625
# Fitness of the best solution : 18381867.866039466
# Generation :  13626
# Fitness of the best solution : 18381867.866039466
# Generation :  13627
# Fitness of the best solution : 18381867.866039466
# Generation :  13628
# Fitness of the best solution : 18381867.866039466
# Generation :  13629
# Fitness of the best solution : 18381867.866039466
# Generation :  13630
# Fitness of the best solution : 18381867.866039466
# Generation :  13631
# Fitness of the best solution : 18381867.866039466
# Generation :  13632
# Fitness of the best solution : 18381867.866039466
# Generation :  13633
# Fitness of the best solution : 18381867.866039466
# Generation :  13634
# Fitness of the best solution : 18381867.866039466
# Generation :  13635
# Fitness of the best solution : 18381867.866039466
# Generation :  13636
# Fitness of the best solution : 18381867.866039466
# Generation :  13637
# Fitness of the best solution : 18381867.866039466
# Generation :  13638
# Fitness of the best solution : 18381867.866039466
# Generation :  13639
# Fitness of the best solution : 18381867.866039466
# Generation :  13640
# Fitness of the best solution : 18381867.866039466
# Generation :  13641
# Fitness of the best solution : 18381867.866039466
# Generation :  13642
# Fitness of the best solution : 18381867.866039466
# Generation :  13643
# Fitness of the best solution : 18381867.866039466
# Generation :  13644
# Fitness of the best solution : 18381867.866039466
# Generation :  13645
# Fitness of the best solution : 18381867.866039466
# Generation :  13646
# Fitness of the best solution : 18381867.866039466
# Generation :  13647
# Fitness of the best solution : 18381867.866039466
# Generation :  13648
# Fitness of the best solution : 18381867.866039466
# Generation :  13649
# Fitness of the best solution : 18381867.866039466
# Generation :  13650
# Fitness of the best solution : 18381867.866039466
# Generation :  13651
# Fitness of the best solution : 18381867.866039466
# Generation :  13652
# Fitness of the best solution : 18381867.866039466
# Generation :  13653
# Fitness of the best solution : 18381867.866039466
# Generation :  13654
# Fitness of the best solution : 18381867.866039466
# Generation :  13655
# Fitness of the best solution : 18381867.866039466
# Generation :  13656
# Fitness of the best solution : 18381867.866039466
# Generation :  13657
# Fitness of the best solution : 18381867.866039466
# Generation :  13658
# Fitness of the best solution : 18381867.866039466
# Generation :  13659
# Fitness of the best solution : 18381867.866039466
# Generation :  13660
# Fitness of the best solution : 18381867.866039466
# Generation :  13661
# Fitness of the best solution : 18381867.866039466
# Generation :  13662
# Fitness of the best solution : 18381867.866039466
# Generation :  13663
# Fitness of the best solution : 18381867.866039466
# Generation :  13664
# Fitness of the best solution : 18381867.866039466
# Generation :  13665
# Fitness of the best solution : 18381867.866039466
# Generation :  13666
# Fitness of the best solution : 18381867.866039466
# Generation :  13667
# Fitness of the best solution : 18381867.866039466
# Generation :  13668
# Fitness of the best solution : 18381867.866039466
# Generation :  13669
# Fitness of the best solution : 18381867.866039466
# Generation :  13670
# Fitness of the best solution : 18381867.866039466
# Generation :  13671
# Fitness of the best solution : 18381867.866039466
# Generation :  13672
# Fitness of the best solution : 18381867.866039466
# Generation :  13673
# Fitness of the best solution : 18381867.866039466
# Generation :  13674
# Fitness of the best solution : 22431760.45738983
# Generation :  13675
# Fitness of the best solution : 22431760.45738983
# Generation :  13676
# Fitness of the best solution : 22431760.45738983
# Generation :  13677
# Fitness of the best solution : 22431760.45738983
# Generation :  13678
# Fitness of the best solution : 22431760.45738983
# Generation :  13679
# Fitness of the best solution : 22431760.45738983
# Generation :  13680
# Fitness of the best solution : 22431760.45738983
# Generation :  13681
# Fitness of the best solution : 22431760.45738983
# Generation :  13682
# Fitness of the best solution : 22431760.45738983
# Generation :  13683
# Fitness of the best solution : 22431760.45738983
# Generation :  13684
# Fitness of the best solution : 22431760.45738983
# Generation :  13685
# Fitness of the best solution : 22431760.45738983
# Generation :  13686
# Fitness of the best solution : 22431760.45738983
# Generation :  13687
# Fitness of the best solution : 22431760.45738983
# Generation :  13688
# Fitness of the best solution : 22431760.45738983
# Generation :  13689
# Fitness of the best solution : 22431760.45738983
# Generation :  13690
# Fitness of the best solution : 22431760.45738983
# Generation :  13691
# Fitness of the best solution : 22431760.45738983
# Generation :  13692
# Fitness of the best solution : 22431760.45738983
# Generation :  13693
# Fitness of the best solution : 22431760.45738983
# Generation :  13694
# Fitness of the best solution : 22431760.45738983
# Generation :  13695
# Fitness of the best solution : 22431760.45738983
# Generation :  13696
# Fitness of the best solution : 22431760.45738983
# Generation :  13697
# Fitness of the best solution : 22431760.45738983
# Generation :  13698
# Fitness of the best solution : 22431760.45738983
# Generation :  13699
# Fitness of the best solution : 22431760.45738983
# Generation :  13700
# Fitness of the best solution : 22431760.45738983
# Generation :  13701
# Fitness of the best solution : 22431760.45738983
# Generation :  13702
# Fitness of the best solution : 22431760.45738983
# Generation :  13703
# Fitness of the best solution : 22431760.45738983
# Generation :  13704
# Fitness of the best solution : 22431760.45738983
# Generation :  13705
# Fitness of the best solution : 22431760.45738983
# Generation :  13706
# Fitness of the best solution : 22431760.45738983
# Generation :  13707
# Fitness of the best solution : 22431760.45738983
# Generation :  13708
# Fitness of the best solution : 22431760.45738983
# Generation :  13709
# Fitness of the best solution : 22431760.45738983
# Generation :  13710
# Fitness of the best solution : 22431760.45738983
# Generation :  13711
# Fitness of the best solution : 22431760.45738983
# Generation :  13712
# Fitness of the best solution : 22431760.45738983
# Generation :  13713
# Fitness of the best solution : 22431760.45738983
# Generation :  13714
# Fitness of the best solution : 22431760.45738983
# Generation :  13715
# Fitness of the best solution : 22431760.45738983
# Generation :  13716
# Fitness of the best solution : 22431760.45738983
# Generation :  13717
# Fitness of the best solution : 22431760.45738983
# Generation :  13718
# Fitness of the best solution : 22431760.45738983
# Generation :  13719
# Fitness of the best solution : 22431760.45738983
# Generation :  13720
# Fitness of the best solution : 22431760.45738983
# Generation :  13721
# Fitness of the best solution : 22431760.45738983
# Generation :  13722
# Fitness of the best solution : 22431760.45738983
# Generation :  13723
# Fitness of the best solution : 22431760.45738983
# Generation :  13724
# Fitness of the best solution : 22431760.45738983
# Generation :  13725
# Fitness of the best solution : 22431760.45738983
# Generation :  13726
# Fitness of the best solution : 22431760.45738983
# Generation :  13727
# Fitness of the best solution : 22431760.45738983
# Generation :  13728
# Fitness of the best solution : 22431760.45738983
# Generation :  13729
# Fitness of the best solution : 22431760.45738983
# Generation :  13730
# Fitness of the best solution : 22431760.45738983
# Generation :  13731
# Fitness of the best solution : 22431760.45738983
# Generation :  13732
# Fitness of the best solution : 22431760.45738983
# Generation :  13733
# Fitness of the best solution : 22431760.45738983
# Generation :  13734
# Fitness of the best solution : 22431760.45738983
# Generation :  13735
# Fitness of the best solution : 22431760.45738983
# Generation :  13736
# Fitness of the best solution : 22431760.45738983
# Generation :  13737
# Fitness of the best solution : 22431760.45738983
# Generation :  13738
# Fitness of the best solution : 22431760.45738983
# Generation :  13739
# Fitness of the best solution : 22431760.45738983
# Generation :  13740
# Fitness of the best solution : 22431760.45738983
# Generation :  13741
# Fitness of the best solution : 22431760.45738983
# Generation :  13742
# Fitness of the best solution : 22431760.45738983
# Generation :  13743
# Fitness of the best solution : 22431760.45738983
# Generation :  13744
# Fitness of the best solution : 22431760.45738983
# Generation :  13745
# Fitness of the best solution : 22431760.45738983
# Generation :  13746
# Fitness of the best solution : 22431760.45738983
# Generation :  13747
# Fitness of the best solution : 22431760.45738983
# Generation :  13748
# Fitness of the best solution : 22431760.45738983
# Generation :  13749
# Fitness of the best solution : 22431760.45738983
# Generation :  13750
# Fitness of the best solution : 22431760.45738983
# Generation :  13751
# Fitness of the best solution : 22431760.45738983
# Generation :  13752
# Fitness of the best solution : 22431760.45738983
# Generation :  13753
# Fitness of the best solution : 22431760.45738983
# Generation :  13754
# Fitness of the best solution : 22431760.45738983
# Generation :  13755
# Fitness of the best solution : 22431760.45738983
# Generation :  13756
# Fitness of the best solution : 22431760.45738983
# Generation :  13757
# Fitness of the best solution : 22431760.45738983
# Generation :  13758
# Fitness of the best solution : 22431760.45738983
# Generation :  13759
# Fitness of the best solution : 22431760.45738983
# Generation :  13760
# Fitness of the best solution : 22431760.45738983
# Generation :  13761
# Fitness of the best solution : 22431760.45738983
# Generation :  13762
# Fitness of the best solution : 22431760.45738983
# Generation :  13763
# Fitness of the best solution : 22431760.45738983
# Generation :  13764
# Fitness of the best solution : 22431760.45738983
# Generation :  13765
# Fitness of the best solution : 22431760.45738983
# Generation :  13766
# Fitness of the best solution : 22431760.45738983
# Generation :  13767
# Fitness of the best solution : 22431760.45738983
# Generation :  13768
# Fitness of the best solution : 22431760.45738983
# Generation :  13769
# Fitness of the best solution : 22431760.45738983
# Generation :  13770
# Fitness of the best solution : 22431760.45738983
# Generation :  13771
# Fitness of the best solution : 22431760.45738983
# Generation :  13772
# Fitness of the best solution : 22431760.45738983
# Generation :  13773
# Fitness of the best solution : 22431760.45738983
# Generation :  13774
# Fitness of the best solution : 22431760.45738983
# Generation :  13775
# Fitness of the best solution : 22431760.45738983
# Generation :  13776
# Fitness of the best solution : 22431760.45738983
# Generation :  13777
# Fitness of the best solution : 22431760.45738983
# Generation :  13778
# Fitness of the best solution : 22431760.45738983
# Generation :  13779
# Fitness of the best solution : 22431760.45738983
# Generation :  13780
# Fitness of the best solution : 22431760.45738983
# Generation :  13781
# Fitness of the best solution : 22431760.45738983
# Generation :  13782
# Fitness of the best solution : 22431760.45738983
# Generation :  13783
# Fitness of the best solution : 22431760.45738983
# Generation :  13784
# Fitness of the best solution : 22431760.45738983
# Generation :  13785
# Fitness of the best solution : 22431760.45738983
# Generation :  13786
# Fitness of the best solution : 22431760.45738983
# Generation :  13787
# Fitness of the best solution : 22431760.45738983
# Generation :  13788
# Fitness of the best solution : 22431760.45738983
# Generation :  13789
# Fitness of the best solution : 22431760.45738983
# Generation :  13790
# Fitness of the best solution : 22431760.45738983
# Generation :  13791
# Fitness of the best solution : 22431760.45738983
# Generation :  13792
# Fitness of the best solution : 22431760.45738983
# Generation :  13793
# Fitness of the best solution : 22431760.45738983
# Generation :  13794
# Fitness of the best solution : 22431760.45738983
# Generation :  13795
# Fitness of the best solution : 22431760.45738983
# Generation :  13796
# Fitness of the best solution : 22431760.45738983
# Generation :  13797
# Fitness of the best solution : 22431760.45738983
# Generation :  13798
# Fitness of the best solution : 22431760.45738983
# Generation :  13799
# Fitness of the best solution : 22431760.45738983
# Generation :  13800
# Fitness of the best solution : 22431760.45738983
# Generation :  13801
# Fitness of the best solution : 22431760.45738983
# Generation :  13802
# Fitness of the best solution : 22431760.45738983
# Generation :  13803
# Fitness of the best solution : 22431760.45738983
# Generation :  13804
# Fitness of the best solution : 22431760.45738983
# Generation :  13805
# Fitness of the best solution : 22431760.45738983
# Generation :  13806
# Fitness of the best solution : 22431760.45738983
# Generation :  13807
# Fitness of the best solution : 22431760.45738983
# Generation :  13808
# Fitness of the best solution : 22431760.45738983
# Generation :  13809
# Fitness of the best solution : 22431760.45738983
# Generation :  13810
# Fitness of the best solution : 22431760.45738983
# Generation :  13811
# Fitness of the best solution : 22431760.45738983
# Generation :  13812
# Fitness of the best solution : 22431760.45738983
# Generation :  13813
# Fitness of the best solution : 22431760.45738983
# Generation :  13814
# Fitness of the best solution : 22431760.45738983
# Generation :  13815
# Fitness of the best solution : 22431760.45738983
# Generation :  13816
# Fitness of the best solution : 22431760.45738983
# Generation :  13817
# Fitness of the best solution : 22431760.45738983
# Generation :  13818
# Fitness of the best solution : 22431760.45738983
# Generation :  13819
# Fitness of the best solution : 22431760.45738983
# Generation :  13820
# Fitness of the best solution : 22431760.45738983
# Generation :  13821
# Fitness of the best solution : 22431760.45738983
# Generation :  13822
# Fitness of the best solution : 22431760.45738983
# Generation :  13823
# Fitness of the best solution : 22431760.45738983
# Generation :  13824
# Fitness of the best solution : 22431760.45738983
# Generation :  13825
# Fitness of the best solution : 22431760.45738983
# Generation :  13826
# Fitness of the best solution : 22431760.45738983
# Generation :  13827
# Fitness of the best solution : 22431760.45738983
# Generation :  13828
# Fitness of the best solution : 22431760.45738983
# Generation :  13829
# Fitness of the best solution : 22431760.45738983
# Generation :  13830
# Fitness of the best solution : 22431760.45738983
# Generation :  13831
# Fitness of the best solution : 22431760.45738983
# Generation :  13832
# Fitness of the best solution : 22431760.45738983
# Generation :  13833
# Fitness of the best solution : 22431760.45738983
# Generation :  13834
# Fitness of the best solution : 22431760.45738983
# Generation :  13835
# Fitness of the best solution : 22431760.45738983
# Generation :  13836
# Fitness of the best solution : 22431760.45738983
# Generation :  13837
# Fitness of the best solution : 22431760.45738983
# Generation :  13838
# Fitness of the best solution : 22431760.45738983
# Generation :  13839
# Fitness of the best solution : 22431760.45738983
# Generation :  13840
# Fitness of the best solution : 22431760.45738983
# Generation :  13841
# Fitness of the best solution : 22431760.45738983
# Generation :  13842
# Fitness of the best solution : 22431760.45738983
# Generation :  13843
# Fitness of the best solution : 22431760.45738983
# Generation :  13844
# Fitness of the best solution : 22431760.45738983
# Generation :  13845
# Fitness of the best solution : 22431760.45738983
# Generation :  13846
# Fitness of the best solution : 22431760.45738983
# Generation :  13847
# Fitness of the best solution : 22431760.45738983
# Generation :  13848
# Fitness of the best solution : 22431760.45738983
# Generation :  13849
# Fitness of the best solution : 22431760.45738983
# Generation :  13850
# Fitness of the best solution : 22431760.45738983
# Generation :  13851
# Fitness of the best solution : 22431760.45738983
# Generation :  13852
# Fitness of the best solution : 22431760.45738983
# Generation :  13853
# Fitness of the best solution : 22431760.45738983
# Generation :  13854
# Fitness of the best solution : 22431760.45738983
# Generation :  13855
# Fitness of the best solution : 22431760.45738983
# Generation :  13856
# Fitness of the best solution : 22431760.45738983
# Generation :  13857
# Fitness of the best solution : 22431760.45738983
# Generation :  13858
# Fitness of the best solution : 22431760.45738983
# Generation :  13859
# Fitness of the best solution : 22431760.45738983
# Generation :  13860
# Fitness of the best solution : 22431760.45738983
# Generation :  13861
# Fitness of the best solution : 22431760.45738983
# Generation :  13862
# Fitness of the best solution : 22431760.45738983
# Generation :  13863
# Fitness of the best solution : 22431760.45738983
# Generation :  13864
# Fitness of the best solution : 22431760.45738983
# Generation :  13865
# Fitness of the best solution : 22431760.45738983
# Generation :  13866
# Fitness of the best solution : 22431760.45738983
# Generation :  13867
# Fitness of the best solution : 22431760.45738983
# Generation :  13868
# Fitness of the best solution : 22431760.45738983
# Generation :  13869
# Fitness of the best solution : 22431760.45738983
# Generation :  13870
# Fitness of the best solution : 22431760.45738983
# Generation :  13871
# Fitness of the best solution : 22431760.45738983
# Generation :  13872
# Fitness of the best solution : 22431760.45738983
# Generation :  13873
# Fitness of the best solution : 22431760.45738983
# Generation :  13874
# Fitness of the best solution : 22431760.45738983
# Generation :  13875
# Fitness of the best solution : 22431760.45738983
# Generation :  13876
# Fitness of the best solution : 22431760.45738983
# Generation :  13877
# Fitness of the best solution : 22431760.45738983
# Generation :  13878
# Fitness of the best solution : 22431760.45738983
# Generation :  13879
# Fitness of the best solution : 22431760.45738983
# Generation :  13880
# Fitness of the best solution : 22431760.45738983
# Generation :  13881
# Fitness of the best solution : 22431760.45738983
# Generation :  13882
# Fitness of the best solution : 22431760.45738983
# Generation :  13883
# Fitness of the best solution : 22431760.45738983
# Generation :  13884
# Fitness of the best solution : 22431760.45738983
# Generation :  13885
# Fitness of the best solution : 22431760.45738983
# Generation :  13886
# Fitness of the best solution : 22431760.45738983
# Generation :  13887
# Fitness of the best solution : 22431760.45738983
# Generation :  13888
# Fitness of the best solution : 22431760.45738983
# Generation :  13889
# Fitness of the best solution : 22431760.45738983
# Generation :  13890
# Fitness of the best solution : 22431760.45738983
# Generation :  13891
# Fitness of the best solution : 22431760.45738983
# Generation :  13892
# Fitness of the best solution : 22431760.45738983
# Generation :  13893
# Fitness of the best solution : 22431760.45738983
# Generation :  13894
# Fitness of the best solution : 22431760.45738983
# Generation :  13895
# Fitness of the best solution : 22431760.45738983
# Generation :  13896
# Fitness of the best solution : 22431760.45738983
# Generation :  13897
# Fitness of the best solution : 22431760.45738983
# Generation :  13898
# Fitness of the best solution : 22431760.45738983
# Generation :  13899
# Fitness of the best solution : 22431760.45738983
# Generation :  13900
# Fitness of the best solution : 22431760.45738983
# Generation :  13901
# Fitness of the best solution : 22431760.45738983
# Generation :  13902
# Fitness of the best solution : 22431760.45738983
# Generation :  13903
# Fitness of the best solution : 22431760.45738983
# Generation :  13904
# Fitness of the best solution : 22431760.45738983
# Generation :  13905
# Fitness of the best solution : 22431760.45738983
# Generation :  13906
# Fitness of the best solution : 22431760.45738983
# Generation :  13907
# Fitness of the best solution : 22431760.45738983
# Generation :  13908
# Fitness of the best solution : 22431760.45738983
# Generation :  13909
# Fitness of the best solution : 22431760.45738983
# Generation :  13910
# Fitness of the best solution : 22431760.45738983
# Generation :  13911
# Fitness of the best solution : 22431760.45738983
# Generation :  13912
# Fitness of the best solution : 22431760.45738983
# Generation :  13913
# Fitness of the best solution : 22431760.45738983
# Generation :  13914
# Fitness of the best solution : 22431760.45738983
# Generation :  13915
# Fitness of the best solution : 22431760.45738983
# Generation :  13916
# Fitness of the best solution : 22431760.45738983
# Generation :  13917
# Fitness of the best solution : 22431760.45738983
# Generation :  13918
# Fitness of the best solution : 22431760.45738983
# Generation :  13919
# Fitness of the best solution : 22431760.45738983
# Generation :  13920
# Fitness of the best solution : 22431760.45738983
# Generation :  13921
# Fitness of the best solution : 22431760.45738983
# Generation :  13922
# Fitness of the best solution : 22431760.45738983
# Generation :  13923
# Fitness of the best solution : 22431760.45738983
# Generation :  13924
# Fitness of the best solution : 22431760.45738983
# Generation :  13925
# Fitness of the best solution : 22431760.45738983
# Generation :  13926
# Fitness of the best solution : 22431760.45738983
# Generation :  13927
# Fitness of the best solution : 22431760.45738983
# Generation :  13928
# Fitness of the best solution : 22431760.45738983
# Generation :  13929
# Fitness of the best solution : 22431760.45738983
# Generation :  13930
# Fitness of the best solution : 22431760.45738983
# Generation :  13931
# Fitness of the best solution : 22431760.45738983
# Generation :  13932
# Fitness of the best solution : 22431760.45738983
# Generation :  13933
# Fitness of the best solution : 22431760.45738983
# Generation :  13934
# Fitness of the best solution : 22431760.45738983
# Generation :  13935
# Fitness of the best solution : 22431760.45738983
# Generation :  13936
# Fitness of the best solution : 22431760.45738983
# Generation :  13937
# Fitness of the best solution : 22431760.45738983
# Generation :  13938
# Fitness of the best solution : 22431760.45738983
# Generation :  13939
# Fitness of the best solution : 22431760.45738983
# Generation :  13940
# Fitness of the best solution : 22431760.45738983
# Generation :  13941
# Fitness of the best solution : 22431760.45738983
# Generation :  13942
# Fitness of the best solution : 22431760.45738983
# Generation :  13943
# Fitness of the best solution : 22431760.45738983
# Generation :  13944
# Fitness of the best solution : 22431760.45738983
# Generation :  13945
# Fitness of the best solution : 22431760.45738983
# Generation :  13946
# Fitness of the best solution : 22431760.45738983
# Generation :  13947
# Fitness of the best solution : 22431760.45738983
# Generation :  13948
# Fitness of the best solution : 22431760.45738983
# Generation :  13949
# Fitness of the best solution : 22431760.45738983
# Generation :  13950
# Fitness of the best solution : 22431760.45738983
# Generation :  13951
# Fitness of the best solution : 22431760.45738983
# Generation :  13952
# Fitness of the best solution : 22431760.45738983
# Generation :  13953
# Fitness of the best solution : 22431760.45738983
# Generation :  13954
# Fitness of the best solution : 22431760.45738983
# Generation :  13955
# Fitness of the best solution : 22431760.45738983
# Generation :  13956
# Fitness of the best solution : 22431760.45738983
# Generation :  13957
# Fitness of the best solution : 22431760.45738983
# Generation :  13958
# Fitness of the best solution : 22431760.45738983
# Generation :  13959
# Fitness of the best solution : 22431760.45738983
# Generation :  13960
# Fitness of the best solution : 22431760.45738983
# Generation :  13961
# Fitness of the best solution : 22431760.45738983
# Generation :  13962
# Fitness of the best solution : 22431760.45738983
# Generation :  13963
# Fitness of the best solution : 22431760.45738983
# Generation :  13964
# Fitness of the best solution : 22431760.45738983
# Generation :  13965
# Fitness of the best solution : 22431760.45738983
# Generation :  13966
# Fitness of the best solution : 22431760.45738983
# Generation :  13967
# Fitness of the best solution : 22431760.45738983
# Generation :  13968
# Fitness of the best solution : 22431760.45738983
# Generation :  13969
# Fitness of the best solution : 22431760.45738983
# Generation :  13970
# Fitness of the best solution : 22431760.45738983
# Generation :  13971
# Fitness of the best solution : 22431760.45738983
# Generation :  13972
# Fitness of the best solution : 22431760.45738983
# Generation :  13973
# Fitness of the best solution : 22431760.45738983
# Generation :  13974
# Fitness of the best solution : 22431760.45738983
# Generation :  13975
# Fitness of the best solution : 22431760.45738983
# Generation :  13976
# Fitness of the best solution : 22431760.45738983
# Generation :  13977
# Fitness of the best solution : 22431760.45738983
# Generation :  13978
# Fitness of the best solution : 22431760.45738983
# Generation :  13979
# Fitness of the best solution : 22431760.45738983
# Generation :  13980
# Fitness of the best solution : 22431760.45738983
# Generation :  13981
# Fitness of the best solution : 22431760.45738983
# Generation :  13982
# Fitness of the best solution : 22431760.45738983
# Generation :  13983
# Fitness of the best solution : 22431760.45738983
# Generation :  13984
# Fitness of the best solution : 22431760.45738983
# Generation :  13985
# Fitness of the best solution : 22431760.45738983
# Generation :  13986
# Fitness of the best solution : 22431760.45738983
# Generation :  13987
# Fitness of the best solution : 22431760.45738983
# Generation :  13988
# Fitness of the best solution : 22431760.45738983
# Generation :  13989
# Fitness of the best solution : 22431760.45738983
# Generation :  13990
# Fitness of the best solution : 22431760.45738983
# Generation :  13991
# Fitness of the best solution : 22431760.45738983
# Generation :  13992
# Fitness of the best solution : 22431760.45738983
# Generation :  13993
# Fitness of the best solution : 22431760.45738983
# Generation :  13994
# Fitness of the best solution : 22431760.45738983
# Generation :  13995
# Fitness of the best solution : 22431760.45738983
# Generation :  13996
# Fitness of the best solution : 22431760.45738983
# Generation :  13997
# Fitness of the best solution : 22431760.45738983
# Generation :  13998
# Fitness of the best solution : 22431760.45738983
# Generation :  13999
# Fitness of the best solution : 22431760.45738983
# Generation :  14000
# Fitness of the best solution : 22431760.45738983
# Generation :  14001
# Fitness of the best solution : 22431760.45738983
# Generation :  14002
# Fitness of the best solution : 22431760.45738983
# Generation :  14003
# Fitness of the best solution : 22431760.45738983
# Generation :  14004
# Fitness of the best solution : 22431760.45738983
# Generation :  14005
# Fitness of the best solution : 22431760.45738983
# Generation :  14006
# Fitness of the best solution : 22431760.45738983
# Generation :  14007
# Fitness of the best solution : 22431760.45738983
# Generation :  14008
# Fitness of the best solution : 22431760.45738983
# Generation :  14009
# Fitness of the best solution : 22431760.45738983
# Generation :  14010
# Fitness of the best solution : 22431760.45738983
# Generation :  14011
# Fitness of the best solution : 22431760.45738983
# Generation :  14012
# Fitness of the best solution : 22431760.45738983
# Generation :  14013
# Fitness of the best solution : 22431760.45738983
# Generation :  14014
# Fitness of the best solution : 22431760.45738983
# Generation :  14015
# Fitness of the best solution : 22431760.45738983
# Generation :  14016
# Fitness of the best solution : 22431760.45738983
# Generation :  14017
# Fitness of the best solution : 22431760.45738983
# Generation :  14018
# Fitness of the best solution : 22431760.45738983
# Generation :  14019
# Fitness of the best solution : 22431760.45738983
# Generation :  14020
# Fitness of the best solution : 22431760.45738983
# Generation :  14021
# Fitness of the best solution : 22431760.45738983
# Generation :  14022
# Fitness of the best solution : 22431760.45738983
# Generation :  14023
# Fitness of the best solution : 22431760.45738983
# Generation :  14024
# Fitness of the best solution : 22431760.45738983
# Generation :  14025
# Fitness of the best solution : 22431760.45738983
# Generation :  14026
# Fitness of the best solution : 22431760.45738983
# Generation :  14027
# Fitness of the best solution : 22431760.45738983
# Generation :  14028
# Fitness of the best solution : 22431760.45738983
# Generation :  14029
# Fitness of the best solution : 22431760.45738983
# Generation :  14030
# Fitness of the best solution : 22431760.45738983
# Generation :  14031
# Fitness of the best solution : 22431760.45738983
# Generation :  14032
# Fitness of the best solution : 22431760.45738983
# Generation :  14033
# Fitness of the best solution : 22431760.45738983
# Generation :  14034
# Fitness of the best solution : 22431760.45738983
# Generation :  14035
# Fitness of the best solution : 22431760.45738983
# Generation :  14036
# Fitness of the best solution : 22431760.45738983
# Generation :  14037
# Fitness of the best solution : 22431760.45738983
# Generation :  14038
# Fitness of the best solution : 22431760.45738983
# Generation :  14039
# Fitness of the best solution : 22431760.45738983
# Generation :  14040
# Fitness of the best solution : 22431760.45738983
# Generation :  14041
# Fitness of the best solution : 22431760.45738983
# Generation :  14042
# Fitness of the best solution : 22431760.45738983
# Generation :  14043
# Fitness of the best solution : 22431760.45738983
# Generation :  14044
# Fitness of the best solution : 22431760.45738983
# Generation :  14045
# Fitness of the best solution : 22431760.45738983
# Generation :  14046
# Fitness of the best solution : 22431760.45738983
# Generation :  14047
# Fitness of the best solution : 22431760.45738983
# Generation :  14048
# Fitness of the best solution : 22431760.45738983
# Generation :  14049
# Fitness of the best solution : 22431760.45738983
# Generation :  14050
# Fitness of the best solution : 22431760.45738983
# Generation :  14051
# Fitness of the best solution : 22431760.45738983
# Generation :  14052
# Fitness of the best solution : 22431760.45738983
# Generation :  14053
# Fitness of the best solution : 22431760.45738983
# Generation :  14054
# Fitness of the best solution : 22431760.45738983
# Generation :  14055
# Fitness of the best solution : 22431760.45738983
# Generation :  14056
# Fitness of the best solution : 22431760.45738983
# Generation :  14057
# Fitness of the best solution : 22431760.45738983
# Generation :  14058
# Fitness of the best solution : 22431760.45738983
# Generation :  14059
# Fitness of the best solution : 22431760.45738983
# Generation :  14060
# Fitness of the best solution : 22431760.45738983
# Generation :  14061
# Fitness of the best solution : 22431760.45738983
# Generation :  14062
# Fitness of the best solution : 22431760.45738983
# Generation :  14063
# Fitness of the best solution : 22431760.45738983
# Generation :  14064
# Fitness of the best solution : 22431760.45738983
# Generation :  14065
# Fitness of the best solution : 22431760.45738983
# Generation :  14066
# Fitness of the best solution : 22431760.45738983
# Generation :  14067
# Fitness of the best solution : 22431760.45738983
# Generation :  14068
# Fitness of the best solution : 22431760.45738983
# Generation :  14069
# Fitness of the best solution : 22431760.45738983
# Generation :  14070
# Fitness of the best solution : 22431760.45738983
# Generation :  14071
# Fitness of the best solution : 22431760.45738983
# Generation :  14072
# Fitness of the best solution : 22431760.45738983
# Generation :  14073
# Fitness of the best solution : 22431760.45738983
# Generation :  14074
# Fitness of the best solution : 22431760.45738983
# Generation :  14075
# Fitness of the best solution : 22431760.45738983
# Generation :  14076
# Fitness of the best solution : 22431760.45738983
# Generation :  14077
# Fitness of the best solution : 22431760.45738983
# Generation :  14078
# Fitness of the best solution : 22431760.45738983
# Generation :  14079
# Fitness of the best solution : 22431760.45738983
# Generation :  14080
# Fitness of the best solution : 22431760.45738983
# Generation :  14081
# Fitness of the best solution : 22431760.45738983
# Generation :  14082
# Fitness of the best solution : 22431760.45738983
# Generation :  14083
# Fitness of the best solution : 22431760.45738983
# Generation :  14084
# Fitness of the best solution : 22431760.45738983
# Generation :  14085
# Fitness of the best solution : 22431760.45738983
# Generation :  14086
# Fitness of the best solution : 22431760.45738983
# Generation :  14087
# Fitness of the best solution : 22431760.45738983
# Generation :  14088
# Fitness of the best solution : 22431760.45738983
# Generation :  14089
# Fitness of the best solution : 22431760.45738983
# Generation :  14090
# Fitness of the best solution : 22431760.45738983
# Generation :  14091
# Fitness of the best solution : 22431760.45738983
# Generation :  14092
# Fitness of the best solution : 22431760.45738983
# Generation :  14093
# Fitness of the best solution : 22431760.45738983
# Generation :  14094
# Fitness of the best solution : 22431760.45738983
# Generation :  14095
# Fitness of the best solution : 22431760.45738983
# Generation :  14096
# Fitness of the best solution : 22431760.45738983
# Generation :  14097
# Fitness of the best solution : 22431760.45738983
# Generation :  14098
# Fitness of the best solution : 22431760.45738983
# Generation :  14099
# Fitness of the best solution : 22431760.45738983
# Generation :  14100
# Fitness of the best solution : 22431760.45738983
# Generation :  14101
# Fitness of the best solution : 22431760.45738983
# Generation :  14102
# Fitness of the best solution : 22431760.45738983
# Generation :  14103
# Fitness of the best solution : 22431760.45738983
# Generation :  14104
# Fitness of the best solution : 22431760.45738983
# Generation :  14105
# Fitness of the best solution : 22431760.45738983
# Generation :  14106
# Fitness of the best solution : 22431760.45738983
# Generation :  14107
# Fitness of the best solution : 22431760.45738983
# Generation :  14108
# Fitness of the best solution : 22431760.45738983
# Generation :  14109
# Fitness of the best solution : 22431760.45738983
# Generation :  14110
# Fitness of the best solution : 22431760.45738983
# Generation :  14111
# Fitness of the best solution : 22431760.45738983
# Generation :  14112
# Fitness of the best solution : 22431760.45738983
# Generation :  14113
# Fitness of the best solution : 22431760.45738983
# Generation :  14114
# Fitness of the best solution : 22431760.45738983
# Generation :  14115
# Fitness of the best solution : 22431760.45738983
# Generation :  14116
# Fitness of the best solution : 22431760.45738983
# Generation :  14117
# Fitness of the best solution : 22431760.45738983
# Generation :  14118
# Fitness of the best solution : 22431760.45738983
# Generation :  14119
# Fitness of the best solution : 22431760.45738983
# Generation :  14120
# Fitness of the best solution : 22431760.45738983
# Generation :  14121
# Fitness of the best solution : 22431760.45738983
# Generation :  14122
# Fitness of the best solution : 22431760.45738983
# Generation :  14123
# Fitness of the best solution : 22431760.45738983
# Generation :  14124
# Fitness of the best solution : 22431760.45738983
# Generation :  14125
# Fitness of the best solution : 22431760.45738983
# Generation :  14126
# Fitness of the best solution : 22431760.45738983
# Generation :  14127
# Fitness of the best solution : 22431760.45738983
# Generation :  14128
# Fitness of the best solution : 22431760.45738983
# Generation :  14129
# Fitness of the best solution : 22431760.45738983
# Generation :  14130
# Fitness of the best solution : 22431760.45738983
# Generation :  14131
# Fitness of the best solution : 22431760.45738983
# Generation :  14132
# Fitness of the best solution : 22431760.45738983
# Generation :  14133
# Fitness of the best solution : 22431760.45738983
# Generation :  14134
# Fitness of the best solution : 22431760.45738983
# Generation :  14135
# Fitness of the best solution : 22431760.45738983
# Generation :  14136
# Fitness of the best solution : 22431760.45738983
# Generation :  14137
# Fitness of the best solution : 22431760.45738983
# Generation :  14138
# Fitness of the best solution : 22431760.45738983
# Generation :  14139
# Fitness of the best solution : 22431760.45738983
# Generation :  14140
# Fitness of the best solution : 22431760.45738983
# Generation :  14141
# Fitness of the best solution : 22431760.45738983
# Generation :  14142
# Fitness of the best solution : 22431760.45738983
# Generation :  14143
# Fitness of the best solution : 22431760.45738983
# Generation :  14144
# Fitness of the best solution : 22431760.45738983
# Generation :  14145
# Fitness of the best solution : 22431760.45738983
# Generation :  14146
# Fitness of the best solution : 22431760.45738983
# Generation :  14147
# Fitness of the best solution : 22431760.45738983
# Generation :  14148
# Fitness of the best solution : 22431760.45738983
# Generation :  14149
# Fitness of the best solution : 22431760.45738983
# Generation :  14150
# Fitness of the best solution : 22431760.45738983
# Generation :  14151
# Fitness of the best solution : 22431760.45738983
# Generation :  14152
# Fitness of the best solution : 22431760.45738983
# Generation :  14153
# Fitness of the best solution : 22431760.45738983
# Generation :  14154
# Fitness of the best solution : 22431760.45738983
# Generation :  14155
# Fitness of the best solution : 22431760.45738983
# Generation :  14156
# Fitness of the best solution : 22431760.45738983
# Generation :  14157
# Fitness of the best solution : 22431760.45738983
# Generation :  14158
# Fitness of the best solution : 22431760.45738983
# Generation :  14159
# Fitness of the best solution : 22431760.45738983
# Generation :  14160
# Fitness of the best solution : 22431760.45738983
# Generation :  14161
# Fitness of the best solution : 22431760.45738983
# Generation :  14162
# Fitness of the best solution : 22431760.45738983
# Generation :  14163
# Fitness of the best solution : 22431760.45738983
# Generation :  14164
# Fitness of the best solution : 22431760.45738983
# Generation :  14165
# Fitness of the best solution : 22431760.45738983
# Generation :  14166
# Fitness of the best solution : 22431760.45738983
# Generation :  14167
# Fitness of the best solution : 22431760.45738983
# Generation :  14168
# Fitness of the best solution : 22431760.45738983
# Generation :  14169
# Fitness of the best solution : 22431760.45738983
# Generation :  14170
# Fitness of the best solution : 22431760.45738983
# Generation :  14171
# Fitness of the best solution : 22431760.45738983
# Generation :  14172
# Fitness of the best solution : 22431760.45738983
# Generation :  14173
# Fitness of the best solution : 22431760.45738983
# Generation :  14174
# Fitness of the best solution : 22431760.45738983
# Generation :  14175
# Fitness of the best solution : 22431760.45738983
# Generation :  14176
# Fitness of the best solution : 22431760.45738983
# Generation :  14177
# Fitness of the best solution : 22431760.45738983
# Generation :  14178
# Fitness of the best solution : 22431760.45738983
# Generation :  14179
# Fitness of the best solution : 22431760.45738983
# Generation :  14180
# Fitness of the best solution : 22431760.45738983
# Generation :  14181
# Fitness of the best solution : 22431760.45738983
# Generation :  14182
# Fitness of the best solution : 22431760.45738983
# Generation :  14183
# Fitness of the best solution : 22431760.45738983
# Generation :  14184
# Fitness of the best solution : 22431760.45738983
# Generation :  14185
# Fitness of the best solution : 22431760.45738983
# Generation :  14186
# Fitness of the best solution : 22431760.45738983
# Generation :  14187
# Fitness of the best solution : 22431760.45738983
# Generation :  14188
# Fitness of the best solution : 22431760.45738983
# Generation :  14189
# Fitness of the best solution : 22431760.45738983
# Generation :  14190
# Fitness of the best solution : 22431760.45738983
# Generation :  14191
# Fitness of the best solution : 22431760.45738983
# Generation :  14192
# Fitness of the best solution : 22431760.45738983
# Generation :  14193
# Fitness of the best solution : 22431760.45738983
# Generation :  14194
# Fitness of the best solution : 22431760.45738983
# Generation :  14195
# Fitness of the best solution : 22431760.45738983
# Generation :  14196
# Fitness of the best solution : 22431760.45738983
# Generation :  14197
# Fitness of the best solution : 22431760.45738983
# ...
# Generation :  14314
# Fitness of the best solution : 22431760.45738983
# Generation :  14315
# Fitness of the best solution : 22431760.45738983
# Generation :  14316
# Fitness of the best solution : 22431760.45738983
# Generation :  14317
# Fitness of the best solution : 22431760.45738983
# Generation :  14318
# Fitness of the best solution : 22431760.45738983
# Generation :  14319
# Fitness of the best solution : 22431760.45738983
# Generation :  14320
# Fitness of the best solution : 22431760.45738983
# Generation :  14321
# Fitness of the best solution : 22431760.45738983
# Generation :  14322
# Fitness of the best solution : 22431760.45738983
# Generation :  14323
# Fitness of the best solution : 22431760.45738983
# Generation :  14324
# Fitness of the best solution : 22431760.45738983
# Generation :  14325
# Fitness of the best solution : 22431760.45738983
# Generation :  14326
# Fitness of the best solution : 22431760.45738983
# Generation :  14327
# Fitness of the best solution : 22431760.45738983
# Generation :  14328
# Fitness of the best solution : 22431760.45738983
# Generation :  14329
# Fitness of the best solution : 22431760.45738983
# Generation :  14330
# Fitness of the best solution : 22431760.45738983
# Generation :  14331
# Fitness of the best solution : 22431760.45738983
# Generation :  14332
# Fitness of the best solution : 22431760.45738983
# Generation :  14333
# Fitness of the best solution : 22431760.45738983
# Generation :  14334
# Fitness of the best solution : 22431760.45738983
# Generation :  14335
# Fitness of the best solution : 22431760.45738983
# Generation :  14336
# Fitness of the best solution : 22431760.45738983
# Generation :  14337
# Fitness of the best solution : 22431760.45738983
# Generation :  14338
# Fitness of the best solution : 22431760.45738983
# Generation :  14339
# Fitness of the best solution : 22431760.45738983
# Generation :  14340
# Fitness of the best solution : 22431760.45738983
# Generation :  14341
# Fitness of the best solution : 22431760.45738983
# Generation :  14342
# Fitness of the best solution : 22431760.45738983
# Generation :  14343
# Fitness of the best solution : 22431760.45738983
# Generation :  14344
# Fitness of the best solution : 22431760.45738983
# Generation :  14345
# Fitness of the best solution : 22431760.45738983
# Generation :  14346
# Fitness of the best solution : 22431760.45738983
# Generation :  14347
# Fitness of the best solution : 22431760.45738983
# Generation :  14348
# Fitness of the best solution : 22431760.45738983
# Generation :  14349
# Fitness of the best solution : 22431760.45738983
# Generation :  14350
# Fitness of the best solution : 22431760.45738983
# Generation :  14351
# Fitness of the best solution : 22431760.45738983
# Generation :  14352
# Fitness of the best solution : 22431760.45738983
# Generation :  14353
# Fitness of the best solution : 22431760.45738983
# Generation :  14354
# Fitness of the best solution : 22431760.45738983
# Generation :  14355
# Fitness of the best solution : 22431760.45738983
# Generation :  14356
# Fitness of the best solution : 22431760.45738983
# Generation :  14357
# Fitness of the best solution : 22431760.45738983
# Generation :  14358
# Fitness of the best solution : 22431760.45738983
# Generation :  14359
# Fitness of the best solution : 22431760.45738983
# Generation :  14360
# Fitness of the best solution : 22431760.45738983
# Generation :  14361
# Fitness of the best solution : 22431760.45738983
# Generation :  14362
# Fitness of the best solution : 22431760.45738983
# Generation :  14363
# Fitness of the best solution : 22431760.45738983
# Generation :  14364
# Fitness of the best solution : 22431760.45738983
# Generation :  14365
# Fitness of the best solution : 22431760.45738983
# Generation :  14366
# Fitness of the best solution : 22431760.45738983
# Generation :  14367
# Fitness of the best solution : 22431760.45738983
# Generation :  14368
# Fitness of the best solution : 22431760.45738983
# Generation :  14369
# Fitness of the best solution : 22431760.45738983
# Generation :  14370
# Fitness of the best solution : 22431760.45738983
# Generation :  14371
# Fitness of the best solution : 22431760.45738983
# Generation :  14372
# Fitness of the best solution : 22431760.45738983
# Generation :  14373
# Fitness of the best solution : 22431760.45738983
# Generation :  14374
# Fitness of the best solution : 22431760.45738983
# Generation :  14375
# Fitness of the best solution : 22431760.45738983
# Generation :  14376
# Fitness of the best solution : 22431760.45738983
# Generation :  14377
# Fitness of the best solution : 22431760.45738983
# Generation :  14378
# Fitness of the best solution : 22431760.45738983
# Generation :  14379
# Fitness of the best solution : 22431760.45738983
# Generation :  14380
# Fitness of the best solution : 22431760.45738983
# Generation :  14381
# Fitness of the best solution : 22431760.45738983
# Generation :  14382
# Fitness of the best solution : 22431760.45738983
# Generation :  14383
# Fitness of the best solution : 22431760.45738983
# Generation :  14384
# Fitness of the best solution : 22431760.45738983
# Generation :  14385
# Fitness of the best solution : 22431760.45738983
# Generation :  14386
# Fitness of the best solution : 22431760.45738983
# Generation :  14387
# Fitness of the best solution : 22431760.45738983
# Generation :  14388
# Fitness of the best solution : 22431760.45738983
# Generation :  14389
# Fitness of the best solution : 22431760.45738983
# Generation :  14390
# Fitness of the best solution : 22431760.45738983
# Generation :  14391
# Fitness of the best solution : 22431760.45738983
# Generation :  14392
# Fitness of the best solution : 22431760.45738983
# Generation :  14393
# Fitness of the best solution : 22431760.45738983
# Generation :  14394
# Fitness of the best solution : 22431760.45738983
# Generation :  14395
# Fitness of the best solution : 22431760.45738983
# Generation :  14396
# Fitness of the best solution : 22431760.45738983
# Generation :  14397
# Fitness of the best solution : 22431760.45738983
# Generation :  14398
# Fitness of the best solution : 22431760.45738983
# Generation :  14399
# Fitness of the best solution : 22431760.45738983
# Generation :  14400
# Fitness of the best solution : 22431760.45738983
# Generation :  14401
# Fitness of the best solution : 22431760.45738983
# Generation :  14402
# Fitness of the best solution : 22431760.45738983
# Generation :  14403
# Fitness of the best solution : 22431760.45738983
# Generation :  14404
# Fitness of the best solution : 22431760.45738983
# Generation :  14405
# Fitness of the best solution : 22431760.45738983
# Generation :  14406
# Fitness of the best solution : 22431760.45738983
# Generation :  14407
# Fitness of the best solution : 22431760.45738983
# Generation :  14408
# Fitness of the best solution : 22431760.45738983
# Generation :  14409
# Fitness of the best solution : 22431760.45738983
# Generation :  14410
# Fitness of the best solution : 22431760.45738983
# Generation :  14411
# Fitness of the best solution : 22431760.45738983
# Generation :  14412
# Fitness of the best solution : 22431760.45738983
# Generation :  14413
# Fitness of the best solution : 22431760.45738983
# Generation :  14414
# Fitness of the best solution : 22431760.45738983
# Generation :  14415
# Fitness of the best solution : 22431760.45738983
# Generation :  14416
# Fitness of the best solution : 22431760.45738983
# Generation :  14417
# Fitness of the best solution : 22431760.45738983
# Generation :  14418
# Fitness of the best solution : 22431760.45738983
# Generation :  14419
# Fitness of the best solution : 22431760.45738983
# Generation :  14420
# Fitness of the best solution : 22431760.45738983
# Generation :  14421
# Fitness of the best solution : 22431760.45738983
# Generation :  14422
# Fitness of the best solution : 22431760.45738983
# Generation :  14423
# Fitness of the best solution : 22431760.45738983
# Generation :  14424
# Fitness of the best solution : 22431760.45738983
# Generation :  14425
# Fitness of the best solution : 22431760.45738983
# Generation :  14426
# Fitness of the best solution : 22431760.45738983
# Generation :  14427
# Fitness of the best solution : 22431760.45738983
# Generation :  14428
# Fitness of the best solution : 22431760.45738983
# Generation :  14429
# Fitness of the best solution : 22431760.45738983
# Generation :  14430
# Fitness of the best solution : 22431760.45738983
# Generation :  14431
# Fitness of the best solution : 22431760.45738983
# Generation :  14432
# Fitness of the best solution : 22431760.45738983
# Generation :  14433
# Fitness of the best solution : 22431760.45738983
# Generation :  14434
# Fitness of the best solution : 22431760.45738983
# Generation :  14435
# Fitness of the best solution : 22431760.45738983
# Generation :  14436
# Fitness of the best solution : 22431760.45738983
# Generation :  14437
# Fitness of the best solution : 22431760.45738983
# Generation :  14438
# Fitness of the best solution : 22431760.45738983
# Generation :  14439
# Fitness of the best solution : 22431760.45738983
# Generation :  14440
# Fitness of the best solution : 22431760.45738983
# Generation :  14441
# Fitness of the best solution : 22431760.45738983
# Generation :  14442
# Fitness of the best solution : 22431760.45738983
# Generation :  14443
# Fitness of the best solution : 22431760.45738983
# Generation :  14444
# Fitness of the best solution : 22431760.45738983
# Generation :  14445
# Fitness of the best solution : 22431760.45738983
# Generation :  14446
# Fitness of the best solution : 22431760.45738983
# Generation :  14447
# Fitness of the best solution : 22431760.45738983
# Generation :  14448
# Fitness of the best solution : 22431760.45738983
# Generation :  14449
# Fitness of the best solution : 22431760.45738983
# Generation :  14450
# Fitness of the best solution : 22431760.45738983
# [Errno 22] Invalid argument: 'genetic_instances/first_trial.pkl'
# Traceback (most recent call last):
#   File "C:\Users\tjaou104\AppData\Local\anaconda3\Lib\site-packages\pygad\pygad.py", line 2127, in run
#     r = self.on_generation(self)
#         ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\tjaou104\AppData\Local\Temp\ipykernel_2884\3714351650.py", line 36, in on_gen
#     ga_instance.save(filename=f'genetic_instances/{instance_name}')
#   File "C:\Users\tjaou104\AppData\Local\anaconda3\Lib\site-packages\pygad\pygad.py", line 2228, in save
#     with open(filename + ".pkl", 'wb') as file:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# OSError: [Errno 22] Invalid argument: 'genetic_instances/first_trial.pkl'
# Generation :  14451
# Fitness of the best solution : 22431760.45738983
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\site-packages\pygad\pygad.py:2127, in GA.run(self)
#    2126 if not (self.on_generation is None):
# -> 2127     r = self.on_generation(self)
#    2128     if type(r) is str and r.lower() == "stop":
#    2129         # Before aborting the loop, save the fitness value of the best solution.
#    2130         # _, best_solution_fitness, _ = self.best_solution()
#
# Cell In[203], line 36, in on_gen(ga_instance)
#      35 instance_name = 'first_trial'
# ---> 36 ga_instance.save(filename=f'genetic_instances/{instance_name}')
#      38 # Save plot every 100 generations
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pygad\pygad.py:2228, in GA.save(self, filename)
#    2227 cloudpickle_serialized_object = cloudpickle.dumps(self)
# -> 2228 with open(filename + ".pkl", 'wb') as file:
#    2229     file.write(cloudpickle_serialized_object)
#
# OSError: [Errno 22] Invalid argument: 'genetic_instances/first_trial.pkl'
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[235], line 3
#       1 import matplotlib.pyplot as plt
# ----> 3 ga_instance.run()
#       4 ga_instance.plot_fitness()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pygad\pygad.py:2182, in GA.run(self)
#    2181 self.logger.exception(ex)
# -> 2182 sys.exit(-1)
#
# SystemExit: -1
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:2097, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2094 if exception_only:
#    2095     stb = ['An exception has occurred, use %tb to see '
#    2096            'the full traceback.\n']
# -> 2097     stb.extend(self.InteractiveTB.get_exception_only(etype,
#    2098                                                      value))
#    2099 else:
#    2101     def contains_exceptiongroup(val):
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\IPython\core\ultratb.py:710, in ListTB.get_exception_only(self, etype, value)
#     702 def get_exception_only(self, etype, value):
#     703     """Only print the exception type and message, without a traceback.
#     704
#     705     Parameters
#    (...)
#     708     value : exception value
#     709     """
# --> 710     return ListTB.structured_traceback(self, etype, value)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\IPython\core\ultratb.py:568, in ListTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     565     chained_exc_ids.add(id(exception[1]))
#     566     chained_exceptions_tb_offset = 0
#     567     out_list = (
# --> 568         self.structured_traceback(
#     569             etype,
#     570             evalue,
#     571             (etb, chained_exc_ids),  # type: ignore
#     572             chained_exceptions_tb_offset,
#     573             context,
#     574         )
#     575         + chained_exception_message
#     576         + out_list)
#     578 return out_list
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\IPython\core\ultratb.py:1435, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1433 else:
#    1434     self.tb = etb
# -> 1435 return FormattedTB.structured_traceback(
#    1436     self, etype, evalue, etb, tb_offset, number_of_lines_of_context
#    1437 )
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\IPython\core\ultratb.py:1326, in FormattedTB.structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1323 mode = self.mode
#    1324 if mode in self.verbose_modes:
#    1325     # Verbose modes need a full traceback
# -> 1326     return VerboseTB.structured_traceback(
#    1327         self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1328     )
#    1329 elif mode == 'Minimal':
#    1330     return ListTB.get_exception_only(self, etype, value)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\IPython\core\ultratb.py:1173, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1164 def structured_traceback(
#    1165     self,
#    1166     etype: type,
#    (...)
#    1170     number_of_lines_of_context: int = 5,
#    1171 ):
#    1172     """Return a nice text document describing the traceback."""
# -> 1173     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1174                                                            tb_offset)
#    1176     colors = self.Colors  # just a shorthand + quicker name lookup
#    1177     colorsnormal = colors.Normal  # used a lot
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\IPython\core\ultratb.py:1063, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1060 assert isinstance(tb_offset, int)
#    1061 head = self.prepare_header(str(etype), self.long_header)
#    1062 records = (
# -> 1063     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#    1064 )
#    1066 frames = []
#    1067 skipped = 0
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\IPython\core\ultratb.py:1131, in VerboseTB.get_records(self, etb, number_of_lines_of_context, tb_offset)
#    1129 while cf is not None:
#    1130     try:
# -> 1131         mod = inspect.getmodule(cf.tb_frame)
#    1132         if mod is not None:
#    1133             mod_name = mod.__name__
#
# AttributeError: 'tuple' object has no attribute 'tb_frame'

# %% [markdown]
# # Analyzing the Solution of the GA

# %% [markdown]
# extract the solution, and reshape it in an interpretable form

# %%
solution, solution_fitness, solution_idx = ga_instance.best_solution()
print("Parameters of the best solution : {solution}".format(solution=solution))
print("Fitness value of the best solution = {solution_fitness}".format(solution_fitness=solution_fitness))
# Out:
# Parameters of the best solution : [-0.75526277  8.48945697  9.0768959  ...  0.13772215 -2.45173486
#  -8.43124877]
# Fitness value of the best solution = 22431760.45738983

# %% [markdown]
# Save the genetic instance

# %%
instance_name = 'first_trial'
ga_instance.save(filename=f'genetic_instances/{instance_name}')

# %% [markdown]
# Let's analyze what we've made

# %%
# Let's pick an LG beam to analyze

field = list_of_OAMs[0].oamBeam 

# Create the phase map by reshaping the solution array

reshape_phase_1 = np.reshape(a=solution[0:N**2], newshape = (N,N))
reshape_phase_2 = np.reshape(a=solution[N**2:2*N**2], newshape=(N,N))
phase_map_1 = np.exp(1j*reshape_phase_1)
phase_map_2 = np.exp(1j*reshape_phase_2)

# modulate the field by the first phase map 

field_mod_1 = field*phase_map_1

TotInt(field_mod_1)

# let's simulate the propagation of the lens

field_lens, _ = propFF(field_mod_1,maxx,la,fourier_lens)

# modulate the field by the second phase map 

field_mod_2 = field_lens*phase_map_2

TotInt(field_mod_2)

# simulate the lens field again. This is the final field. 

field_lens_2, _ = propFF(field_mod_2, maxx, la, fourier_lens)


TotInt(field_lens_2)

# compute the field intensity 

final_field_int = np.abs(field_lens_2)**2

# %%
plt.imshow(final_field_int)

# %%
plt.imshow(np.abs(output_chans[1])**2)
